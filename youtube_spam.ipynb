# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from skimpy import skim

# %%
df=pd.read_csv(r'C:\Users\Saravanan\OneDrive\Desktop\drive\youtube spam\Youtube-Spam-Dataset.csv')

# %%
df
# Out:
#                                        COMMENT_ID                AUTHOR  \
# 0     LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1     LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A           adam riyati
# 2     LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8      Evgeny Murashkin
# 3             z13jhp0bxqncu512g22wvzkasxmvvzjaz04       ElNino Melendez
# 4             z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# ...                                           ...                   ...
# 1951  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA          Katie Mettam
# 1952  _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI  Sabina Pearson-Smith
# 1953  _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs         jeffrey jules
# 1954  _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0        Aishlin Maciel
# 1955  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA           Latin Bosch
#
#                             DATE  \
# 0            2013-11-07T06:20:48
# ...

# %%
df.describe()
# Out:
#              CLASS
# count  1956.000000
# mean      0.513804
# std       0.499937
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1956 entries, 0 to 1955
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COMMENT_ID  1956 non-null   object
#  1   AUTHOR      1956 non-null   object
#  2   DATE        1711 non-null   object
#  3   CONTENT     1956 non-null   object
#  4   VIDEO_NAME  1956 non-null   object
#  5   CLASS       1956 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 91.8+ KB

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1956   │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 6      │ │ int32       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
df.isna().sum()
# Out:
# COMMENT_ID      0
# AUTHOR          0
# DATE          245
# CONTENT         0
# VIDEO_NAME      0
# CLASS           0
# dtype: int64

# %%
df['DATE']=pd.to_datetime(df['DATE'],errors='coerce')

# %%
df['DATE']=df['DATE'].fillna(df['DATE'].median())

# %%
df.isna().sum()
# Out:
# COMMENT_ID    0
# AUTHOR        0
# DATE          0
# CONTENT       0
# VIDEO_NAME    0
# CLASS         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %% [markdown]
#  Distribution of CLASS

# %%
sns.countplot(x='CLASS',data=df)
plt.title('Distribution of Class')
plt.show()

# %% [markdown]
# Unique Video Names and Most Commented Videos

# %%
print(f"Unique Video Names: {df['VIDEO_NAME'].nunique()}")
most_commented_videos = df['VIDEO_NAME'].value_counts().head(10)
print(most_commented_videos)
# Out:
# Unique Video Names: 5
# VIDEO_NAME
# Eminem - Love The Way You Lie ft. Rihanna                 448
# LMFAO - Party Rock Anthem ft. Lauren Bennett, GoonRock    438
# Shakira - Waka Waka                                       370
# PSY - GANGNAM STYLE(?????) M/V                            350
# Katy Perry - Roar                                         350
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=most_commented_videos,y=most_commented_videos.index,palette='viridis')
plt.title('Top 10 Most Commented Videos')
plt.xlabel('Numberof Comments')
plt.ylabel('Videos')
plt.show()
# Out:
# C:\Users\Saravanan\AppData\Local\Temp\ipykernel_20944\4147240599.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
import plotly.express as px

# %%
fig_videos = px.bar(
    x=most_commented_videos.values,
    y=most_commented_videos.index,
    labels={'x':'Number of Comments', 'y':'Video Name'},
    title='Top 10 Most Commented Videos',
    orientation='h',
    color=most_commented_videos.values,
    color_continuous_scale='Viridis'
)
fig_videos.update_layout(coloraxis_showscale=False)
fig_videos.show()

# %% [markdown]
# Unique Authors and Top Commenters

# %%
print(f"Unique Authors:{df['AUTHOR'].nunique()}")
# Out:
# Unique Authors:1792

# %%
top_comments=df['AUTHOR'].value_counts().head(10)
print(top_comments)
# Out:
# AUTHOR
# M.E.S              8
# 5000palo           7
# Louis Bryant       7
# Shadrach Grentz    7
# DanteBTV           6
# LuckyMusiqLive     5
# Derek Moya         5
# Hidden Love        5
# Laura Brown        4
# James Cook         4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=top_comments.values,y=top_comments.index,palette='coolwarm')
plt.title("Top 10 Comments")
plt.xlabel("Number of Comments")
plt.ylabel('author')
plt.show()
# Out:
# C:\Users\Saravanan\AppData\Local\Temp\ipykernel_20944\3579764216.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
fig_authors = px.bar(
    x=top_comments.values,
    y=top_comments.index,
    labels={'x':'Number of Comments', 'y':'Author'},
    title='Top 10 Commenters',
    orientation='h',
    color=top_comments.values,
    color_continuous_scale='Portland'
)
fig_authors.update_layout(coloraxis_showscale=False)
fig_authors.show()

# %% [markdown]
# Length of Comments

# %%
plt.figure(figsize=(8,8))
sns.histplot(df['CONTENT'].apply(len),bins=50)
plt.title('Distribution of comment Length')
plt.show()

# %% [markdown]
# Word Cloud for Content

# %%
from wordcloud import WordCloud

# %%
word_could=WordCloud(width=800,height=400,background_color='pink').generate(' '.join(df['CONTENT']))
plt.figure(figsize=(10,6))
plt.imshow(word_could,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Temporal Analysis

# %%
df['DATE']=pd.to_datetime(df['DATE'])
df.set_index('DATE',inplace=True)
df['CONTENT'].resample('M').count().plot()
plt.title('Number of Comments over time')
plt.show()
# Out:
# C:\Users\Saravanan\AppData\Local\Temp\ipykernel_20944\2258611165.py:3: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.

# %%
from textblob import TextBlob

# Sentiment Analysis
df['sentiment'] = df['CONTENT'].apply(lambda text: TextBlob(text).sentiment.polarity)

# Visualizing Sentiment Distribution
sns.histplot(df['sentiment'], bins=50, kde=True)
plt.title('Sentiment Polarity Distribution')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Feature and label
X = df['CONTENT']
y = df['CLASS']

# Vectorization
vectorizer = TfidfVectorizer(max_features=5000)
X_vec = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)

# Model training
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluation
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       176
#            1       0.99      0.92      0.95       216
#
#     accuracy                           0.95       392
#    macro avg       0.95      0.95      0.95       392
# weighted avg       0.95      0.95      0.95       392

# %%
import streamlit as st
import plotly.express as px

st.title('YouTube Comment Analysis')

# Sentiment distribution plot
fig_sentiment = px.histogram(df, x='sentiment', nbins=50, title='Sentiment Polarity Distribution')
st.plotly_chart(fig_sentiment)

# Top 10 Most Commented Videos
st.subheader('Top 10 Most Commented Videos')
st.bar_chart(most_commented_videos)

# Top 10 Commenters
# st.subheader('Top 10 Commenters')
# st.bar_chart(top_commenters)
# Out:
# 2024-08-28 16:26:19.314 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 16:26:21.402
# ...
#   command:
#
#     streamlit run c:\Users\Saravanan\OneDrive\Desktop\drive\youtube spam\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-08-28 16:26:21.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 16:26:22.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 16:26:22.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 16:26:22.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
